# %% [markdown]
# **Disclaimer:** The content of this notebook is for informational use only.

# %% [markdown]
# # Web Scraping

# %% [markdown]
# ### Introducción
# Este **notebook** tiene la finalidad de ser una plantilla simple de como obtener datos con Python. Se obtendra datos mediante Web Scraping, el uso de expresiones regulares y visualización.

# %% [markdown]
# ## Web Scraping Using Requests and Beautiful Soup (bs4)

# %% [markdown]
# Podemos encontrar un elemento en la página inspeccionando la página (haga clic con el botón derecho y presione el elemento de inspección). Luego utilizamos una serie de selectores de HTML para encontrar las etiquetas adecuadas que contengan el contenido que nos interesa. El siguiente bloque de código encuentra el texto principal de todo el artículo. Luego, subdividiremos el texto en la tabla correspondiente y lo guardaremos como un objeto de texto.

# %%
# requests para obtener html del sitio web
import requests

from bs4 import BeautifulSoup

# inicializar variables
lista_url = []
lista_product_details_name = []
lista_precio_normal = []
lista_precio_internet = []
lista_precio_ripley = []

URL = 'https://simple.ripley.com.pe/computo/laptops/todas-las-laptops'

# Hacer la solicitud a una URL
req = requests.get(URL)
print(req.status_code)
i = 0
bandera = True
while bandera == True:
#while i < 2:
  
  # Crear un SOUP a partir del contenido del requests
  c = req.content
  soup = BeautifulSoup(c)
  
  # Encuentra el elemento en la página web
  catalog_container = soup.find('div', attrs = {'class': 'catalog-container'})
  
  # Validar si la pagina cuenta con contenido
  if catalog_container is None or len(catalog_container) == 0:
    print("I have nothing to print")
    bandera = False
  else:
    print(catalog_container)
    #for href in catalog_container.find_all('a', href=True):
    for product_item in catalog_container.find_all('a', href=True):
        #print(product_item)
        
        ### FALTA IMAGEN DEL PRODUCTO
        #images-preview-item is-active

        ### URL DE LOS PRODUCTOS ###
        lista_url.append('https://simple.ripley.com.pe'+product_item['href'])

        ### PRODUCTO NOMBRE DETALLE ###
        lista_product_details_name.append(product_item.find('div',attrs = {'class':'catalog-product-details__name'}).text.replace("\"",""))

        ### PRODUCTO PRECIO NORMAL ###
        precio_normal = product_item.find('li',attrs = {'class':'catalog-prices__list-price catalog-prices__lowest'})
        if precio_normal is None or len(precio_normal) == 0:
          lista_precio_normal.append(-1)
          #print("I have nothing to print")
        else:
          lista_precio_normal.append(precio_normal.text.replace("S/ ","").replace(",",""))
          #print(precio_normal.text)

        ### PRODUCTO PRECIO INTERNET ###
        precio_internet = product_item.find('li',attrs = {'class':'catalog-prices__offer-price'})
        if precio_internet is None or len(precio_internet) == 0:
          lista_precio_internet.append(-1)
          #print("I have nothing to print")
        else:
          lista_precio_internet.append(precio_internet.text.replace("S/ ","").replace(",",""))
          #print(precio_normal.text)

        ### PRODUCTO PRECIO INTERNET ###
        precio_ripley = product_item.find('li',attrs = {'class':'catalog-prices__card-price'})
        if precio_ripley is None or len(precio_ripley) == 0:
          lista_precio_ripley.append(-1)
          #print("I have nothing to print")
        else:
          lista_precio_ripley.append(precio_ripley.text.replace("S/ ","").replace(",",""))
          #print(precio_normal.text)

    i += 1
    req = requests.get(URL+'?page='+str(i))
    print(req.status_code)
# Out:
# 200
# <div class="catalog-container"><a class="catalog-product-item catalog-product-item__container col-xs-6 col-sm-6 col-md-4 col-lg-4" href="/lenovo-laptop-ideapad-320-156-amd-a12-2tb-16gb-2gb-2004217985684p"><div class="proportional-image-wrapper catalog-product__image-preview"><div class="proportional-image-wrapper-boundary" style="padding-bottom:74.07407407407408%"></div><div class="images-preview is-pristine"><div class="images-preview-item is-active"><img data-lazy="//home.ripley.com.pe/Attachment/WOP_5/2004217985684/2004217985684_2.jpg" fallback="https://static.ripley.com.pe/images/no-picture.svg"/><div class="lazy-image__loading-container"><img alt="" class="lazy-image__loading" src="https://static.ripley.com.pe/images/loading.gif"/></div></div></div></div><div class="catalog-product-details"><div class="catalog-product-details__logo-container"><div class="brand-logo"><span>LENOVO</span></div></div><div class="catalog-product-details__name">LENOVO LAPTOP IDEAPAD 320 15.6" AMD A12 2TB 16GB 2GB</div><div class="catalog-product-details__prices"><div class="catalog-prices"><meta itemprop="priceCurrency"/><ul class="catalog-prices__list"><li class="catalog-prices__list-price catalog-prices__lowest" title="Precio Normal">S/ 3,099</li><li class="catalog-prices__offer-price" title="Precio Internet">S/ 2,099</li><li class="catalog-prices__card-price" title="Precio Ripley">S/ 1,999 <img alt="Precio Tarjeta Ripley" class="catalog-prices__card-price-image" src="https://static.ripley.com.pe/images/logo-aon.png"/></li></ul></div></div><div class="catalog-product-details__discount-tag">-35%</div><div class="catalog-product-details__event-img"><img alt="En Promoción" src="//home.ripley.com.pe/promo-badges/cyber.png	"/></div></div></a><a class="catalog-product-item catalog-product-item__container col-xs-6 col-sm-6 col-md-4 col-lg-4" href="/hp-laptop-15-da0010la-156-core-i5-1tb-4gb-2004209413775p"><div class="proportional-image-wrapper catalog-product__image-preview"><div class="proportional-image-wrapper-boundary" style="padding-bottom:74.07407407407408%"></div><div class="images-preview is-pristine"><div class="images-preview-item is-active"><img data-lazy="//home.ripley.com.pe/Attachment/WOP_5/2004209413775/2004209413775_2.jpg" fallback="https://static.ripley.com.pe/images/no-picture.svg"/><div class="lazy-image__loading-container"><img alt="" class="lazy-image__loading" src="https://static.ripley.com.pe/images/loading.gif"/></div></div></div></div><div class="catalog-product-details"><div class="catalog-product-details__logo-container"><div class="brand-logo"><span>HP</span></div></div><div class="catalog-product-details__name">HP LAPTOP 15-DA0010LA 15.6" CORE I5 1TB 4GB</div><div class="catalog-product-details__prices"><div class="catalog-prices"><meta itemprop="priceCurrency"/><ul class="catalog-prices__list"><li class="catalog-prices__list-price catalog-prices__lowest" title="Precio Normal">S/ 2,299</li><li class="catalog-prices__offer-price" title="Precio Internet">S/ 1,899</li><li class="catalog-prices__card-price" title="Precio Ripley">S/ 1,799 <img alt="Precio Tarjeta Ripley" class="catalog-prices__card-price-image" src="https://static.ripley.com.pe/images/logo-aon.png"/></li></ul></div></div><div class="catalog-product-details__discount-tag">-22%</div><div class="catalog-product-details__event-img"><img alt="En Promoción" src="//home.ripley.com.pe/promo-badges/cyber.png	"/></div></div></a><a class="catalog-product-item catalog-product-item__container col-xs-6 col-sm-6 col-md-4 col-lg-4" href="/asus-laptop-x507ub-br349t-156-core-i5-1tb-4gb-2gb-2004214537336p"><div class="proportional-image-wrapper catalog-product__image-preview"><div class="proportional-image-wrapper-boundary" style="padding-bottom:74.07407407407408%"></div><div class="images-preview is-pristine"><div class="images-preview-item is-active"><img data-lazy="//home.ripley.com.pe/Attachment/WOP_5/2004214537336/2004214537336_2.jpg" fallback="https://static.ripley.com.pe ...
# 200
# <div class="catalog-container"><a class="catalog-product-item catalog-product-item__container col-xs-6 col-sm-6 col-md-4 col-lg-4" href="/lenovo-laptop-ideapad-320-156-amd-a12-2tb-16gb-2gb-2004217985684p"><div class="proportional-image-wrapper catalog-product__image-preview"><div class="proportional-image-wrapper-boundary" style="padding-bottom:74.07407407407408%"></div><div class="images-preview is-pristine"><div class="images-preview-item is-active"><img data-lazy="//home.ripley.com.pe/Attachment/WOP_5/2004217985684/2004217985684_2.jpg" fallback="https://static.ripley.com.pe/images/no-picture.svg"/><div class="lazy-image__loading-container"><img alt="" class="lazy-image__loading" src="https://static.ripley.com.pe/images/loading.gif"/></div></div></div></div><div class="catalog-product-details"><div class="catalog-product-details__logo-container"><div class="brand-logo"><span>LENOVO</span></div></div><div class="catalog-product-details__name">LENOVO LAPTOP IDEAPAD 320 15.6" AMD A12 2TB 16GB 2GB</div><div class="catalog-product-details__prices"><div class="catalog-prices"><meta itemprop="priceCurrency"/><ul class="catalog-prices__list"><li class="catalog-prices__list-price catalog-prices__lowest" title="Precio Normal">S/ 3,099</li><li class="catalog-prices__offer-price" title="Precio Internet">S/ 2,099</li><li class="catalog-prices__card-price" title="Precio Ripley">S/ 1,999 <img alt="Precio Tarjeta Ripley" class="catalog-prices__card-price-image" src="https://static.ripley.com.pe/images/logo-aon.png"/></li></ul></div></div><div class="catalog-product-details__discount-tag">-35%</div><div class="catalog-product-details__event-img"><img alt="En Promoción" src="//home.ripley.com.pe/promo-badges/cyber.png	"/></div></div></a><a class="catalog-product-item catalog-product-item__container col-xs-6 col-sm-6 col-md-4 col-lg-4" href="/hp-laptop-15-da0010la-156-core-i5-1tb-4gb-2004209413775p"><div class="proportional-image-wrapper catalog-product__image-preview"><div class="proportional-image-wrapper-boundary" style="padding-bottom:74.07407407407408%"></div><div class="images-preview is-pristine"><div class="images-preview-item is-active"><img data-lazy="//home.ripley.com.pe/Attachment/WOP_5/2004209413775/2004209413775_2.jpg" fallback="https://static.ripley.com.pe/images/no-picture.svg"/><div class="lazy-image__loading-container"><img alt="" class="lazy-image__loading" src="https://static.ripley.com.pe/images/loading.gif"/></div></div></div></div><div class="catalog-product-details"><div class="catalog-product-details__logo-container"><div class="brand-logo"><span>HP</span></div></div><div class="catalog-product-details__name">HP LAPTOP 15-DA0010LA 15.6" CORE I5 1TB 4GB</div><div class="catalog-product-details__prices"><div class="catalog-prices"><meta itemprop="priceCurrency"/><ul class="catalog-prices__list"><li class="catalog-prices__list-price catalog-prices__lowest" title="Precio Normal">S/ 2,299</li><li class="catalog-prices__offer-price" title="Precio Internet">S/ 1,899</li><li class="catalog-prices__card-price" title="Precio Ripley">S/ 1,799 <img alt="Precio Tarjeta Ripley" class="catalog-prices__card-price-image" src="https://static.ripley.com.pe/images/logo-aon.png"/></li></ul></div></div><div class="catalog-product-details__discount-tag">-22%</div><div class="catalog-product-details__event-img"><img alt="En Promoción" src="//home.ripley.com.pe/promo-badges/cyber.png	"/></div></div></a><a class="catalog-product-item catalog-product-item__container col-xs-6 col-sm-6 col-md-4 col-lg-4" href="/asus-laptop-x507ub-br349t-156-core-i5-1tb-4gb-2gb-2004214537336p"><div class="proportional-image-wrapper catalog-product__image-preview"><div class="proportional-image-wrapper-boundary" style="padding-bottom:74.07407407407408%"></div><div class="images-preview is-pristine"><div class="images-preview-item is-active"><img data-lazy="//home.ripley.com.pe/Attachment/WOP_5/2004214537336/2004214537336_2.jpg" fallback="https://static.ripley.com.pe ...
# 200
# <div class="catalog-container"><a class="catalog-product-item catalog-product-item__container col-xs-6 col-sm-6 col-md-4 col-lg-4" href="/acer-laptop-aspire-a515-51g-550j-156-core-i5-1tb-4gb-2004209845477p"><div class="proportional-image-wrapper catalog-product__image-preview"><div class="proportional-image-wrapper-boundary" style="padding-bottom:74.07407407407408%"></div><div class="images-preview is-pristine"><div class="images-preview-item is-active"><img data-lazy="//home.ripley.com.pe/Attachment/WOP_5/2004209845477/2004209845477_2.jpg" fallback="https://static.ripley.com.pe/images/no-picture.svg"/><div class="lazy-image__loading-container"><img alt="" class="lazy-image__loading" src="https://static.ripley.com.pe/images/loading.gif"/></div></div></div></div><div class="catalog-product-details"><div class="catalog-product-details__logo-container"><div class="brand-logo"><span>ACER</span></div></div><div class="catalog-product-details__name">ACER LAPTOP ASPIRE A515-51G-550J 15.6" CORE I5 1TB 4GB</div><div class="catalog-product-details__prices"><div class="catalog-prices"><meta itemprop="priceCurrency"/><ul class="catalog-prices__list"><li class="catalog-prices__list-price catalog-prices__lowest" title="Precio Normal">S/ 3,599</li><li class="catalog-prices__offer-price catalog-prices__highest" title="Precio Internet">S/ 2,199</li></ul></div></div><div class="catalog-product-details__discount-tag">-39%</div><div class="catalog-product-details__event-img"><img alt="En Promoción" src="//home.ripley.com.pe/promo-badges/cyber.png	"/></div></div></a><a class="catalog-product-item catalog-product-item__container col-xs-6 col-sm-6 col-md-4 col-lg-4" href="/hp-laptop-15-da0023la-156-core-i5-1tb-4gb-2004214678763p"><div class="proportional-image-wrapper catalog-product__image-preview"><div class="proportional-image-wrapper-boundary" style="padding-bottom:74.07407407407408%"></div><div class="images-preview is-pristine"><div class="images-preview-item is-active"><img data-lazy="//home.ripley.com.pe/Attachment/WOP_5/2004214678763/2004214678763_2.jpg" fallback="https://static.ripley.com.pe/images/no-picture.svg"/><div class="lazy-image__loading-container"><img alt="" class="lazy-image__loading" src="https://static.ripley.com.pe/images/loading.gif"/></div></div></div></div><div class="catalog-product-details"><div class="catalog-product-details__logo-container"><div class="brand-logo"><span></span></div></div><div class="catalog-product-details__name">HP LAPTOP 15-DA0023LA 15.6" CORE I5 1TB 4GB</div><div class="catalog-product-details__prices"><div class="catalog-prices"><meta itemprop="priceCurrency"/><ul class="catalog-prices__list"><li class="catalog-prices__list-price catalog-prices__lowest" title="Precio Normal">S/ 2,399</li><li class="catalog-prices__offer-price" title="Precio Internet">S/ 1,869</li><li class="catalog-prices__card-price" title="Precio Ripley">S/ 1,769 <img alt="Precio Tarjeta Ripley" class="catalog-prices__card-price-image" src="https://static.ripley.com.pe/images/logo-aon.png"/></li></ul></div></div><div class="catalog-product-details__discount-tag">-26%</div><div class="catalog-product-details__event-img"><img alt="En Promoción" src="//home.ripley.com.pe/promo-badges/cyber.png	"/></div></div></a><a class="catalog-product-item catalog-product-item__container col-xs-6 col-sm-6 col-md-4 col-lg-4" href="/lenovo-laptop-yoga-530-14-core-i3-128gb-4gb-2004218074097p"><div class="proportional-image-wrapper catalog-product__image-preview"><div class="proportional-image-wrapper-boundary" style="padding-bottom:74.07407407407408%"></div><div class="images-preview is-pristine"><div class="images-preview-item is-active"><img data-lazy="//home.ripley.com.pe/Attachment/WOP_5/2004218074097/2004218074097_2.jpg" fallback="https://static.ripley.com.pe/images/no-picture.svg"/><div class="lazy-image__loading-container"><img alt="" class="lazy-image__loading" src="https://static.ripley.com.pe/images/loading.gif"/></div></div></div></div> ...
# 200
# <div class="catalog-container"><a class="catalog-product-item catalog-product-item__container col-xs-6 col-sm-6 col-md-4 col-lg-4" href="/lenovo-laptop-yoga-520-14-core-i5-1tb-8gb-2004212839234p"><div class="proportional-image-wrapper catalog-product__image-preview"><div class="proportional-image-wrapper-boundary" style="padding-bottom:74.07407407407408%"></div><div class="images-preview is-pristine"><div class="images-preview-item is-active"><img data-lazy="//home.ripley.com.pe/Attachment/WOP_5/2004212839234/2004212839234_2.jpg" fallback="https://static.ripley.com.pe/images/no-picture.svg"/><div class="lazy-image__loading-container"><img alt="" class="lazy-image__loading" src="https://static.ripley.com.pe/images/loading.gif"/></div></div></div></div><div class="catalog-product-details"><div class="catalog-product-details__logo-container"><div class="brand-logo"><span>LENOVO</span></div></div><div class="catalog-product-details__name">LENOVO LAPTOP YOGA 520 14" CORE I5 1TB 8GB</div><div class="catalog-product-details__prices"><div class="catalog-prices"><meta itemprop="priceCurrency"/><ul class="catalog-prices__list"><li class="catalog-prices__list-price catalog-prices__lowest" title="Precio Normal">S/ 3,899</li><li class="catalog-prices__offer-price catalog-prices__highest" title="Precio Internet">S/ 2,399</li></ul></div></div><div class="catalog-product-details__discount-tag">-38%</div><div class="catalog-product-details__event-img"><img alt="En Promoción" src="//home.ripley.com.pe/promo-badges/cyber.png	"/></div></div></a><a class="catalog-product-item catalog-product-item__container col-xs-6 col-sm-6 col-md-4 col-lg-4" href="/hp-laptop-13-ah0003la-133-core-i5-256gb-ssd-8gb-2004209413812p"><div class="proportional-image-wrapper catalog-product__image-preview"><div class="proportional-image-wrapper-boundary" style="padding-bottom:74.07407407407408%"></div><div class="images-preview is-pristine"><div class="images-preview-item is-active"><img data-lazy="//home.ripley.com.pe/Attachment/WOP_5/2004209413812/2004209413812_2.jpg" fallback="https://static.ripley.com.pe/images/no-picture.svg"/><div class="lazy-image__loading-container"><img alt="" class="lazy-image__loading" src="https://static.ripley.com.pe/images/loading.gif"/></div></div></div></div><div class="catalog-product-details"><div class="catalog-product-details__logo-container"><div class="brand-logo"><span>HP</span></div></div><div class="catalog-product-details__name">HP LAPTOP 13-AH0003LA 13.3" CORE I5 256GB SSD 8GB</div><div class="catalog-product-details__prices"><div class="catalog-prices"><meta itemprop="priceCurrency"/><ul class="catalog-prices__list"><li class="catalog-prices__list-price catalog-prices__lowest" title="Precio Normal">S/ 3,899</li><li class="catalog-prices__offer-price catalog-prices__highest" title="Precio Internet">S/ 3,199</li></ul></div></div><div class="catalog-product-details__discount-tag">-18%</div><div class="catalog-product-details__event-img"><img alt="En Promoción" src="//home.ripley.com.pe/promo-badges/cyber.png	"/></div></div></a><a class="catalog-product-item catalog-product-item__container col-xs-6 col-sm-6 col-md-4 col-lg-4" href="/hp-laptop-14-cd0003la-14-intel-core-i3-500gb-4gb-2004209413782p"><div class="proportional-image-wrapper catalog-product__image-preview"><div class="proportional-image-wrapper-boundary" style="padding-bottom:74.07407407407408%"></div><div class="images-preview is-pristine"><div class="images-preview-item is-active"><img data-lazy="//home.ripley.com.pe/Attachment/WOP_5/2004209413782/2004209413782_2.jpg" fallback="https://static.ripley.com.pe/images/no-picture.svg"/><div class="lazy-image__loading-container"><img alt="" class="lazy-image__loading" src="https://static.ripley.com.pe/images/loading.gif"/></div></div></div></div><div class="catalog-product-details"><div class="catalog-product-details__logo-container"><div class="brand-logo"><span>HP</span></div></div><div class="catalog-product-details__name" ...
# 200
# <div class="catalog-container"><a class="catalog-product-item catalog-product-item__container col-xs-6 col-sm-6 col-md-4 col-lg-4" href="/acer-laptop-nitro-5-an515-52-76p6-156-core-i7-1tb-12gb-2004208916215p"><div class="proportional-image-wrapper catalog-product__image-preview"><div class="proportional-image-wrapper-boundary" style="padding-bottom:74.07407407407408%"></div><div class="images-preview is-pristine"><div class="images-preview-item is-active"><img data-lazy="//home.ripley.com.pe/Attachment/WOP_5/2004208916215/2004208916215_2.jpg" fallback="https://static.ripley.com.pe/images/no-picture.svg"/><div class="lazy-image__loading-container"><img alt="" class="lazy-image__loading" src="https://static.ripley.com.pe/images/loading.gif"/></div></div></div></div><div class="catalog-product-details"><div class="catalog-product-details__logo-container"><div class="brand-logo"><span>ACER</span></div></div><div class="catalog-product-details__name">ACER LAPTOP NITRO 5 AN515-52-76P6 15.6" CORE i7 1TB 12GB</div><div class="catalog-product-details__prices"><div class="catalog-prices"><meta itemprop="priceCurrency"/><ul class="catalog-prices__list"><li class="catalog-prices__list-price catalog-prices__lowest" title="Precio Normal">S/ 4,999</li><li class="catalog-prices__offer-price catalog-prices__highest" title="Precio Internet">S/ 4,499</li></ul></div></div><div class="catalog-product-details__discount-tag">-10%</div><div class="catalog-product-details__event-img"><img alt="En Promoción" src="//home.ripley.com.pe/promo-badges/cyber.png	"/></div></div></a><a class="catalog-product-item catalog-product-item__container col-xs-6 col-sm-6 col-md-4 col-lg-4" href="/acer-laptop-swift-3-sf314-54g-57t9-14-intel-core-i5-1tb-8gb-2gb-2004208939276p"><div class="proportional-image-wrapper catalog-product__image-preview"><div class="proportional-image-wrapper-boundary" style="padding-bottom:74.07407407407408%"></div><div class="images-preview is-pristine"><div class="images-preview-item is-active"><img data-lazy="//home.ripley.com.pe/Attachment/WOP_5/2004208939276/2004208939276_2.jpg" fallback="https://static.ripley.com.pe/images/no-picture.svg"/><div class="lazy-image__loading-container"><img alt="" class="lazy-image__loading" src="https://static.ripley.com.pe/images/loading.gif"/></div></div></div></div><div class="catalog-product-details"><div class="catalog-product-details__logo-container"><div class="brand-logo"><span>ACER</span></div></div><div class="catalog-product-details__name">ACER LAPTOP SWIFT 3 SF314-54G-57T9 14" INTEL CORE i5 1TB 8GB 2GB</div><div class="catalog-product-details__prices"><div class="catalog-prices"><meta itemprop="priceCurrency"/><ul class="catalog-prices__list"><li class="catalog-prices__list-price catalog-prices__lowest" title="Precio Normal">S/ 3,899</li><li class="catalog-prices__offer-price catalog-prices__highest" title="Precio Internet">S/ 3,299</li></ul></div></div><div class="catalog-product-details__discount-tag">-15%</div><div class="catalog-product-details__event-img"><img alt="En Promoción" src="//home.ripley.com.pe/promo-badges/cyber.png	"/></div></div></a><a class="catalog-product-item catalog-product-item__container col-xs-6 col-sm-6 col-md-4 col-lg-4" href="/acer-laptop-ph315-51-79pl-156-core-i7-1tb-16gb-2004212619348p"><div class="proportional-image-wrapper catalog-product__image-preview"><div class="proportional-image-wrapper-boundary" style="padding-bottom:74.07407407407408%"></div><div class="images-preview is-pristine"><div class="images-preview-item is-active"><img data-lazy="//home.ripley.com.pe/Attachment/WOP_5/2004212619348/2004212619348_2.jpg" fallback="https://static.ripley.com.pe/images/no-picture.svg"/><div class="lazy-image__loading-container"><img alt="" class="lazy-image__loading" src="https://static.ripley.com.pe/images/loading.gif"/></div></div></div></div><div class="catalog-product-details"><div class="catalog-product-details__logo-container"><div class="brand-logo"><span>ACER</s ...
# 200
# <div class="catalog-container"><a class="catalog-product-item catalog-product-item__container col-xs-6 col-sm-6 col-md-4 col-lg-4" href="/lenovo-laptop-ideapad-320-14-celeron-n3350-500gb-4gb-2004204578653p"><div class="proportional-image-wrapper catalog-product__image-preview"><div class="proportional-image-wrapper-boundary" style="padding-bottom:74.07407407407408%"></div><div class="images-preview is-pristine"><div class="images-preview-item is-active"><img data-lazy="//home.ripley.com.pe/Attachment/WOP_5/2004204578653/2004204578653_2.jpg" fallback="https://static.ripley.com.pe/images/no-picture.svg"/><div class="lazy-image__loading-container"><img alt="" class="lazy-image__loading" src="https://static.ripley.com.pe/images/loading.gif"/></div></div></div></div><div class="catalog-product-details"><div class="catalog-product-details__logo-container"><div class="brand-logo"><span>LENOVO</span></div></div><div class="catalog-product-details__name">LENOVO LAPTOP IDEAPAD 320 14" CELERON N3350 500GB 4GB</div><div class="catalog-product-details__prices"><div class="catalog-prices"><meta itemprop="priceCurrency"/><ul class="catalog-prices__list"><li class="catalog-prices__list-price catalog-prices__lowest" title="Precio Normal">S/ 1,399</li><li class="catalog-prices__offer-price catalog-prices__highest" title="Precio Internet">S/ 1,199</li></ul></div></div><div class="catalog-product-details__discount-tag">-14%</div><div class="catalog-product-details__event-img"><img alt="En Promoción" src="//home.ripley.com.pe/promo-badges/cyber.png	"/></div></div></a><a class="catalog-product-item catalog-product-item__container col-xs-6 col-sm-6 col-md-4 col-lg-4" href="/lenovo-laptop-ideapad-520-156-core-i5-1tb-12gb-4gb-2004208929895p"><div class="proportional-image-wrapper catalog-product__image-preview"><div class="proportional-image-wrapper-boundary" style="padding-bottom:74.07407407407408%"></div><div class="images-preview is-pristine"><div class="images-preview-item is-active"><img data-lazy="//home.ripley.com.pe/Attachment/WOP_5/2004208929895/2004208929895_2.jpg" fallback="https://static.ripley.com.pe/images/no-picture.svg"/><div class="lazy-image__loading-container"><img alt="" class="lazy-image__loading" src="https://static.ripley.com.pe/images/loading.gif"/></div></div></div></div><div class="catalog-product-details"><div class="catalog-product-details__logo-container"><div class="brand-logo"><span>LENOVO</span></div></div><div class="catalog-product-details__name">LENOVO LAPTOP IDEAPAD 520 15.6" CORE I5 1TB 12GB 4GB</div><div class="catalog-product-details__prices"><div class="catalog-prices"><meta itemprop="priceCurrency"/><ul class="catalog-prices__list"><li class="catalog-prices__list-price catalog-prices__lowest" title="Precio Normal">S/ 3,799</li><li class="catalog-prices__offer-price catalog-prices__highest" title="Precio Internet">S/ 3,099</li></ul></div></div><div class="catalog-product-details__discount-tag">-18%</div><div class="catalog-product-details__event-img"><img alt="En Promoción" src="//home.ripley.com.pe/promo-badges/cyber.png	"/></div></div></a><a class="catalog-product-item catalog-product-item__container col-xs-6 col-sm-6 col-md-4 col-lg-4" href="/lenovo-laptop-ideapad-320-156-amd-a10-1tb-8gb-2004208935506p"><div class="proportional-image-wrapper catalog-product__image-preview"><div class="proportional-image-wrapper-boundary" style="padding-bottom:74.07407407407408%"></div><div class="images-preview is-pristine"><div class="images-preview-item is-active"><img data-lazy="//home.ripley.com.pe/Attachment/WOP_5/2004208935506/2004208935506_2.jpg" fallback="https://static.ripley.com.pe/images/no-picture.svg"/><div class="lazy-image__loading-container"><img alt="" class="lazy-image__loading" src="https://static.ripley.com.pe/images/loading.gif"/></div></div></div></div><div class="catalog-product-details"><div class="catalog-product-details__logo-container"><div class="brand-logo"><span>LENOVO</span></div></div><div clas ...
# 200
# <div class="catalog-container"><a class="catalog-product-item catalog-product-item__container col-xs-6 col-sm-6 col-md-4 col-lg-4" href="/hp-laptop-14-cf0002la-14-core-i3-1tb-4gb-16gb-intel-optane-2004210686908p"><div class="proportional-image-wrapper catalog-product__image-preview"><div class="proportional-image-wrapper-boundary" style="padding-bottom:74.07407407407408%"></div><div class="images-preview is-pristine"><div class="images-preview-item is-active"><img data-lazy="//home.ripley.com.pe/Attachment/WOP_2/2004210686908/2004210686908_2.jpg" fallback="https://static.ripley.com.pe/images/no-picture.svg"/><div class="lazy-image__loading-container"><img alt="" class="lazy-image__loading" src="https://static.ripley.com.pe/images/loading.gif"/></div></div></div></div><div class="catalog-product-details"><div class="catalog-product-details__logo-container"><div class="brand-logo"><span></span></div></div><div class="catalog-product-details__name">HP LAPTOP 14-CF0002LA 14" CORE i3 1TB 4GB + 16GB INTEL OPTANE</div><div class="catalog-product-details__prices"><div class="catalog-prices"><meta itemprop="priceCurrency"/><ul class="catalog-prices__list"><li class="catalog-prices__list-price catalog-prices__lowest" title="Precio Normal">S/ 1,929</li><li class="catalog-prices__offer-price catalog-prices__highest" title="Precio Internet">S/ 1,899</li></ul></div></div><div class="catalog-product-details__discount-tag">-2%</div></div></a><a class="catalog-product-item catalog-product-item__container col-xs-6 col-sm-6 col-md-4 col-lg-4" href="/asus-laptop-tp410uf-ec017t-156-core-i5-1tb-4gb-2gb-2004209381814p"><div class="proportional-image-wrapper catalog-product__image-preview"><div class="proportional-image-wrapper-boundary" style="padding-bottom:74.07407407407408%"></div><div class="images-preview is-pristine"><div class="images-preview-item is-active"><img data-lazy="//home.ripley.com.pe/Attachment/WOP_5/2004209381814/2004209381814_2.jpg" fallback="https://static.ripley.com.pe/images/no-picture.svg"/><div class="lazy-image__loading-container"><img alt="" class="lazy-image__loading" src="https://static.ripley.com.pe/images/loading.gif"/></div></div></div></div><div class="catalog-product-details"><div class="catalog-product-details__logo-container"><div class="brand-logo"><span>ASUS</span></div></div><div class="catalog-product-details__name">ASUS LAPTOP TP410UF-EC017T 15.6" CORE i5 1TB 4GB 2GB</div><div class="catalog-product-details__prices"><div class="catalog-prices"><meta itemprop="priceCurrency"/><ul class="catalog-prices__list"><li class="catalog-prices__list-price catalog-prices__lowest" title="Precio Normal">S/ 2,999</li><li class="catalog-prices__offer-price catalog-prices__highest" title="Precio Internet">S/ 2,899</li></ul></div></div><div class="catalog-product-details__discount-tag">-3%</div><div class="catalog-product-details__event-img"><img alt="En Promoción" src="//home.ripley.com.pe/promo-badges/cyber.png	"/></div></div></a><a class="catalog-product-item catalog-product-item__container col-xs-6 col-sm-6 col-md-4 col-lg-4" href="/huawei-laptop-matebook-x-pro-139-core-i5-256gb-8gb-2004212773651p"><div class="proportional-image-wrapper catalog-product__image-preview"><div class="proportional-image-wrapper-boundary" style="padding-bottom:74.07407407407408%"></div><div class="images-preview is-pristine"><div class="images-preview-item is-active"><img data-lazy="//home.ripley.com.pe/Attachment/WOP_5/2004212773651/2004212773651_2.jpg" fallback="https://static.ripley.com.pe/images/no-picture.svg"/><div class="lazy-image__loading-container"><img alt="" class="lazy-image__loading" src="https://static.ripley.com.pe/images/loading.gif"/></div></div></div></div><div class="catalog-product-details"><div class="catalog-product-details__logo-container"><div class="brand-logo"><span>HUAWEI</span></div></div><div class="catalog-product-details__name">HUAWEI LAPTOP MATEBOOK X PRO 13.9" CORE I5 256GB 8GB</div><div class="catalog-product-d ...
# 200
# I have nothing to print

# %%
import pandas as pd

# Put information into a dataframe
df = pd.DataFrame({'url': lista_url, 
                   'product_details_name': lista_product_details_name,
                   'precio_normal' : lista_precio_normal,
                   'lista_precio_internet' : lista_precio_internet,
                   'lista_precio_ripley' : lista_precio_ripley
                  })

# %%
df
# Out:
#     lista_precio_internet lista_precio_ripley precio_normal  \
# 0                    2099               1999           3099
# 1                    1899               1799           2299
# 2                    2199                  -1          2699
# 3                    1999                  -1          2499
# 4                    2599                  -1          3499
# 5                    2899                  -1          3699
# 6                     999                  -1          1499
# 7                    1999               1899           2399
# 8                    2199                  -1          2799
# 9                    1999                  -1          2399
# 10                   2099                  -1          3199
# 11                   2399                  -1          3099
# 12                   1999                  -1          2699
# 13                   3999                  -1            -1
# 14                   1499                  -1          1899
# 15                   1699               1599           2499
# 16                   1599                  -1          1629
# 17                   3699                  -1          4299
# 18                   3999                  -1          4999
# 19                   5299                  -1            -1
# 20                   1499               1399           1999
# 21                   1799               1699           2399
# 22                   1599                  -1          1899
# 23                   2659                  -1            -1
# 24                   2099               1999           3099
# 25                   1899               1799           2299
# 26                   2199                  -1          2699
# 27                   1999                  -1          2499
# 28                   2599                  -1          3499
# 29                   2899                  -1          3699
# ..                    ...                 ...           ...
# 128                  2599                  -1          2899
# 129                  2999                  -1          3199
# 130                  4499                  -1          5499
# 131                   459                  -1           499
# 132                  3600                  -1          4999
# 133                  2799                  -1          3499
# 134                  1699               1599           1999
# 135                  4950                  -1          5399
# 136                  3600                  -1          4799
# 137                  4399                  -1          5099
# 138                  3099                  -1          3799
# 139                  1699                  -1          2099
# 140                  2200                  -1          3999
# 141                  3359                  -1            -1
# 142                    -1                  -1            -1
# 143                    -1                  -1            -1
# 144                  1899                  -1          1929
# 145                  2899                  -1          2999
# 146                  5769                  -1          6999
# 147                  1899                  -1          2399
# 148                   225                  -1           339
# 149                   599                  -1           999
# 150                  4599                  -1            -1
# 151                  3799                  -1            -1
# 152                  5599                  -1            -1
# 153                  3199                  -1            -1
# 154                  1299                  -1          1399
# 155                  2599                  -1          3299
# 156                  3299                  -1          3899
# 157                  1599               1499           1699
#
#                                   product_details_name  \
# 0    LENOVO LAPTOP IDEAPAD 320 15.6 AMD A12 2TB 16G...
# 1           HP LAPTOP 15-DA0010LA 15.6 CORE I5 1TB 4GB
# 2    ASUS LAPTOP X507UB-BR349T 15.6 CORE i5 1TB 4GB...
# 3    ASUS LAPTOP X505ZA-BR134T 15.6 AMD RYZEN 5 1TB...
# 4    HP LAPTOP 15-DA0016LA 15.6 CORE I7 1TB 4GB +16...
# 5    ACER LAPTOP NITRO 5 AN515-52-57VM 15.6 CORE I5...
# 6    ACER LAPTOP A314-31-C38R 14 INTEL CELERON N335...
# 7    LENOVO LAPTOP YOGA 520 14'' CORE i3 1TB 8GB - ...
# 8    HP LAPTOP 15-DA0024LA 15.6 CORE I5 1TB 4GB +16...
# 9          LENOVO LAPTOP YOGA 520 14'' CORE i3 1TB 4GB
# 10   LENOVO LAPTOP IDEAPAD 330S 15.6 CORE I5 1TB 4G...
# 11   ACER LAPTOP ASPIRE A515-51G-5078 15.6 CORE I5 ...
# 12   ACER LAPTOP ASPIRE SP314-51-31GG 14 CORE I3 1T...
# 13   ASUS LAPTOP FX504GM-E4185T 15.6 CORE i5 1TB 8G...
# 14       ASUS LAPTOP X540BP-GO067T 15.6 AMD A9 1TB 4GB
# 15   ACER LAPTOP ASPIRE A315-41 15.6 AMD RYZEN 5 1T...
# 16          HP LAPTOP 15-DA0007LA 15.6 CORE I3 1TB 4GB
# 17         HP LAPTOP 15-DC0001C 15 CORE i5 1TB 8GB 4GB
# 18     LENOVO LAPTOP YOGA 910 13.9'' CORE i7 256GB 8GB
# 19   ASUS LAPTOP GL703GE-GC093T 17.3 CORE i7 1TB 12...
# 20   LENOVO LAPTOP IDEAPAD 310 15.6'' CORE i3 1TB 4...
# 21   LENOVO LAPTOP IDEAPAD 330S 14 CORE I3 1TB 4GB ...
# 22        HP LAPTOP 14-CM0007LA 14 AMD RYZEN 3 1TB 4GB
# 23      HP LAPTOP 14-CD0008LA 14 INTEL CORE I5 1TB 6GB
# 24   LENOVO LAPTOP IDEAPAD 320 15.6 AMD A12 2TB 16G...
# 25          HP LAPTOP 15-DA0010LA 15.6 CORE I5 1TB 4GB
# 26   ASUS LAPTOP X507UB-BR349T 15.6 CORE i5 1TB 4GB...
# 27   ASUS LAPTOP X505ZA-BR134T 15.6 AMD RYZEN 5 1TB...
# 28   HP LAPTOP 15-DA0016LA 15.6 CORE I7 1TB 4GB +16...
# 29   ACER LAPTOP NITRO 5 AN515-52-57VM 15.6 CORE I5...
# ..                                                 ...
# 128   SAMSUNG GALAXY BOOK 10.6 SM-W620NZWBPEO  BLANCO
# 129  ACER LAPTOP NITRO 5 AN515-51-54EG 15.6 CORE i5...
# 130            LG LAPTOP 14Z980-G 14 CORE I5 256GB 8GB
# 131  ADVANCE LAPTOP NV9801 10 INTEL ATOM x5 Z8350 3...
# 132    HP LAPTOP 13-AD002LA 13.3 CORE I5 4GB 256GB SSD
# 133  LENOVO LAPTOP YOGA 510 15.6 CORE i5 1TB 4GB - ...
# 134  ACER LAPTOP ES1-572-57FT 15.6 INTEL CORE I5 1T...
# 135  HP LAPTOP 17-AN001LA 17.3 CORE I7 1TB 12GB - N...
# 136  ACER LAPTOP NITRO 5 AN515-51-75WG 15.6 CORE i7...
# 137  LENOVO LAPTOP IDEAPAD 720S 14 CORE I7 256GB SS...
# 138  LENOVO LAPTOP IDEAPAD 520 15.6 CORE I7 1TB 8GB...
# 139      LENOVO LAPTOP IDEAPAD 320 15.6 AMD A9 1TB 8GB
# 140        LAPTOP IDEAPAD 510S 15.6'' CORE i7 1TB 12GB
# 141     HP LAPTOP 13-AG0002LA 13 AMD RYZEN 5 256GB 8GB
# 142  ACER LAPTOP ASPIRE E5-774-546B 17.3'' CORE i5 ...
# 143  ASUS LAPTOP X555LA-XX2544T 15.6 INTEL CORE I5 ...
# 144  HP LAPTOP 14-CF0002LA 14 CORE i3 1TB 4GB + 16G...
# 145  ASUS LAPTOP TP410UF-EC017T 15.6 CORE i5 1TB 4G...
# 146  HUAWEI LAPTOP MATEBOOK X PRO 13.9 CORE I5 256G...
# 147  LENOVO ALL IN ONE IDEACENTRE AIO 520 21.5 CORE...
# 148        ADVANCE TABLET PR6145 7 1GB 8GB 3G - BLANCO
# 149  ADVANCE LAPTOP NV7546 13.3 INTEL CELERON 32GB ...
# 150  ASUS LAPTOP N580GD-DM299T 15.6 CORE i7 1TB 8GB...
# 151  ASUS LAPTOP X542UN-DM216T 15.6 CORE i7 1TB 12G...
# 152           LG LAPTOP 5Z980-G 15.6 CORE I7 512GB 8GB
# 153  LENOVO LAPTOP IDEAPAD 330S 15.6 CORE I5 1TB 8G...
# 154    LENOVO LAPTOP IDEAPAD 330 15.6 AMD A6 500GB 4GB
# 155  LENOVO LAPTOP IDEAPAD 330S 15.6 INTEL CORE I5 ...
# 156  LENOVO LAPTOP IDEAPAD 330S 15.6 INTEL CORE I7 ...
# 157      LENOVO LAPTOP IDEAPAD 330S 14 CORE I3 2TB 4GB
#
#                                                    url
# 0    https://simple.ripley.com.pe/lenovo-laptop-ide...
# 1    https://simple.ripley.com.pe/hp-laptop-15-da00...
# 2    https://simple.ripley.com.pe/asus-laptop-x507u...
# 3    https://simple.ripley.com.pe/asus-laptop-x505z...
# 4    https://simple.ripley.com.pe/hp-laptop-15-da00...
# 5    https://simple.ripley.com.pe/acer-laptop-nitro...
# 6    https://simple.ripley.com.pe/acer-laptop-a314-...
# 7    https://simple.ripley.com.pe/lenovo-laptop-yog...
# 8    https://simple.ripley.com.pe/hp-laptop-15-da00...
# 9    https://simple.ripley.com.pe/lenovo-laptop-yog...
# 10   https://simple.ripley.com.pe/lenovo-laptop-ide...
# 11   https://simple.ripley.com.pe/acer-laptop-aspir...
# 12   https://simple.ripley.com.pe/acer-laptop-aspir...
# 13   https://simple.ripley.com.pe/asus-laptop-fx504...
# 14   https://simple.ripley.com.pe/asus-laptop-x540b...
# 15   https://simple.ripley.com.pe/acer-laptop-aspir...
# 16   https://simple.ripley.com.pe/hp-laptop-15-da00...
# 17   https://simple.ripley.com.pe/hp-laptop-15-dc00...
# 18   https://simple.ripley.com.pe/lenovo-laptop-yog...
# 19   https://simple.ripley.com.pe/asus-laptop-gl703...
# 20   https://simple.ripley.com.pe/lenovo-laptop-ide...
# 21   https://simple.ripley.com.pe/lenovo-laptop-ide...
# 22   https://simple.ripley.com.pe/hp-laptop-14-cm00...
# 23   https://simple.ripley.com.pe/hp-laptop-14-cd00...
# 24   https://simple.ripley.com.pe/lenovo-laptop-ide...
# 25   https://simple.ripley.com.pe/hp-laptop-15-da00...
# 26   https://simple.ripley.com.pe/asus-laptop-x507u...
# 27   https://simple.ripley.com.pe/asus-laptop-x505z...
# 28   https://simple.ripley.com.pe/hp-laptop-15-da00...
# 29   https://simple.ripley.com.pe/acer-laptop-nitro...
# ..                                                 ...
# 128  https://simple.ripley.com.pe/samsung-galaxy-bo...
# 129  https://simple.ripley.com.pe/acer-laptop-nitro...
# 130  https://simple.ripley.com.pe/lg-laptop-14z980-...
# 131  https://simple.ripley.com.pe/advance-laptop-nv...
# 132  https://simple.ripley.com.pe/hp-laptop-13-ad00...
# 133  https://simple.ripley.com.pe/lenovo-laptop-yog...
# 134  https://simple.ripley.com.pe/acer-laptop-es1-5...
# 135  https://simple.ripley.com.pe/hp-laptop-17-an00...
# 136  https://simple.ripley.com.pe/acer-laptop-nitro...
# 137  https://simple.ripley.com.pe/lenovo-laptop-ide...
# 138  https://simple.ripley.com.pe/lenovo-laptop-ide...
# 139  https://simple.ripley.com.pe/lenovo-laptop-ide...
# 140  https://simple.ripley.com.pe/laptop-ideapad-51...
# 141  https://simple.ripley.com.pe/hp-laptop-13-ag00...
# 142  https://simple.ripley.com.pe/acer-laptop-aspir...
# 143  https://simple.ripley.com.pe/asus-laptop-x555l...
# 144  https://simple.ripley.com.pe/hp-laptop-14-cf00...
# 145  https://simple.ripley.com.pe/asus-laptop-tp410...
# 146  https://simple.ripley.com.pe/huawei-laptop-mat...
# 147  https://simple.ripley.com.pe/lenovo-all-in-one...
# 148  https://simple.ripley.com.pe/advance-tablet-pr...
# 149  https://simple.ripley.com.pe/advance-laptop-nv...
# 150  https://simple.ripley.com.pe/asus-laptop-n580g...
# 151  https://simple.ripley.com.pe/asus-laptop-x542u...
# 152  https://simple.ripley.com.pe/lg-laptop-5z980-g...
# 153  https://simple.ripley.com.pe/lenovo-laptop-ide...
# 154  https://simple.ripley.com.pe/lenovo-laptop-ide...
# 155  https://simple.ripley.com.pe/lenovo-laptop-ide...
# 156  https://simple.ripley.com.pe/lenovo-laptop-ide...
# 157  https://simple.ripley.com.pe/lenovo-laptop-ide...
#
# [158 rows x 5 columns]
